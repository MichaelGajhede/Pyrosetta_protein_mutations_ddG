# %%
import pandas as pd
import seaborn
import matplotlib

# %%
df = pd.read_csv ('1BV1_mut_old.csv')
print (df)
# Out:
#       Unnamed: 0  resi wt_resn resn      dG_mut       dG_wt       ddG
# 0              0     1       G    G -561.224207 -561.305689  0.081481
# 1              1     1       G    A -562.470357 -561.305689 -1.164668
# 2              2     1       G    L -561.080370 -561.305689  0.225319
# 3              3     1       G    M -561.307800 -561.305689 -0.002111
# 4              4     1       G    F -559.606384 -561.305689  1.699305
# ...          ...   ...     ...  ...         ...         ...       ...
# 3175        3175   159       N    H -560.542682 -561.305689  0.763007
# 3176        3176   159       N    R -562.694315 -561.305689 -1.388626
# 3177        3177   159       N    N -561.319222 -561.305689 -0.013534
# 3178        3178   159       N    D -561.020933 -561.305689  0.284756
# 3179        3179   159       N    T -558.334136 -561.305689  2.971553
#
# [3180 rows x 7 columns]

# %%
df.nlargest(5, ['ddG'])
# Out:
#       Unnamed: 0  resi wt_resn resn      dG_mut       dG_wt        ddG
# 910          910    46       G    P -501.659365 -561.305689  59.646324
# 1010        1010    51       G    P -503.606370 -561.305689  57.699318
# 950          950    48       G    P -504.248222 -561.305689  57.057467
# 1770        1770    89       G    P -516.341348 -561.305689  44.964341
# 670          670    34       A    P -523.960913 -561.305689  37.344776

# %%
df.nsmallest(200, ['ddG'])
# Out:
#       Unnamed: 0  resi wt_resn resn      dG_mut       dG_wt       ddG
# 614          614    31       P    Y -570.973144 -561.305689 -9.667456
# 604          604    31       P    F -570.402894 -561.305689 -9.097205
# 616          616    31       P    R -569.932553 -561.305689 -8.626864
# 607          607    31       P    Q -569.581964 -561.305689 -8.276275
# 615          615    31       P    H -569.421924 -561.305689 -8.116236
# ...          ...   ...     ...  ...         ...         ...       ...
# 2703        2703   136       S    M -562.617073 -561.305689 -1.311384
# 1076        1076    54       K    R -562.613440 -561.305689 -1.307751
# 1082        1082    55       K    L -562.610481 -561.305689 -1.304792
# 3114        3114   156       D    Y -562.604256 -561.305689 -1.298567
# 767          767    39       S    Q -562.598869 -561.305689 -1.293181
#
# [200 rows x 7 columns]

# %%
df_pivot = df.pivot("resi", "resn", "ddG")
df_pivot
# Out:
# resn         A         C         D         E          F          G          H  \
# resi
# 1    -1.164668  0.882804 -1.329161  0.163076   1.699305   0.081481   0.069978
# 2     3.049147  4.129288  4.953940  1.387081   5.642560   6.935664   4.199526
# 3     4.379565  8.127878  4.567443  7.239325   0.131341   6.723868   4.343062
# 4     0.384591  0.280351 -1.607877 -1.171661  -1.452486   2.886138   0.445443
# 5     8.600172  8.200639  7.074685  7.869117  12.244357  12.093748  12.480189
# ...        ...       ...       ...       ...        ...        ...        ...
# 155   1.316708  2.652790  2.034989  0.483871   2.094682   2.668517   2.230951
# 156   1.249486  3.066081  0.003120 -0.435147   1.068658   1.854024   0.654583
# 157  -0.086099  2.643664  2.517958  0.169356   8.814415   4.363414   7.150412
# 158   5.300703  6.682347  1.405026  4.515920   1.421405   6.171448   4.507945
# 159  -1.872041  1.616208  0.284756  0.577600   4.446907  -0.353576   0.763007
#
# resn          I          K         L          M         N          P  \
# resi
# 1      0.728118  -3.852271  0.225319  -0.002111 -3.275613   1.203652
# 2      0.267309   3.660943  1.080066   2.902299  4.462448   4.058561
# 3      4.773144   5.823306  4.774193   6.664148  4.784840   7.685276
# 4     -2.372267  -1.408028 -2.537067   0.198104 -0.005587  -0.782240
# 5      8.347168  15.973596  7.344579  12.592913  7.757098   9.842603
# ...         ...        ...       ...        ...       ...        ...
# 155    3.170979  -2.577121  1.105173   2.320976  2.022561  -4.008303
# 156    2.148749  -0.031039  0.537541   1.381395  0.069813  12.995588
# 157    8.609392   2.022288  7.534925   2.774907  4.139528  13.428969
# 158   15.921998   2.715956  9.258121   5.981658  3.463448  13.364962
# 159    0.801240  -1.475203 -0.610686   0.023319 -0.013534   9.783414
#
# resn         Q          R         S         T          V          W          Y
# resi
# 1    -1.646142  -3.479998 -2.059063 -0.383421  -0.630961   1.747357   1.253168
# 2     1.111753   3.695117  3.945149 -0.162045   0.030811   4.339273   4.589472
# 3     3.849794   7.127243  5.875523  7.427076   5.474662   2.427098   2.052282
# 4    -2.110643  -0.716542  0.140432 -1.239652  -2.673957   2.268010  -2.712195
# 5     7.087144  12.532288  8.893774  7.201516   6.584848  11.817102  12.321846
# ...        ...        ...       ...       ...        ...        ...        ...
# 155  -0.191836   1.717662 -0.710975  1.268523   2.838816   1.965269   2.728327
# 156   0.747077   1.414591 -0.283747  0.156671   1.547256   0.234842  -1.298567
# 157   0.164614   3.465707  1.295640  3.835184   7.401589  11.426944   8.013733
# 158   2.867440   4.790806  6.011840  7.815344  13.958271   3.742578   1.742351
# 159  -0.707066  -1.388626 -1.629929  2.971553  -1.873500   4.241855   0.809710
#
# [159 rows x 20 columns]

# %%
df_mins = df_pivot.min(axis=1) #returns panda series which is an indexed 1d array
df_mins
# Out:
# resi
# 1     -3.852271
# 2     -0.162045
# 3      0.131341
# 4     -2.712195
# 5      6.584848
#          ...
# 155   -4.008303
# 156   -1.298567
# 157   -0.086099
# 158    1.405026
# 159   -1.873500
# Length: 159, dtype: float64

# %%
from Bio import *
from Bio.PDB import PDBParser, PDBIO

# %%
io = PDBIO()
p = PDBParser()

structure = p.get_structure("1bv1", "1bv1_copy.pdb") # input files

for model in structure:
    for chain in model:
        for residue in chain:
            resi = residue.get_id()[1]
            #print(resi)
            bfac = df_mins.loc[resi]
            #print(bfac)
            for atom in residue:  
                atom.set_bfactor(bfac) # set b to ddG min for residue

print(structure)
io.set_structure(structure)
io.save("pymol-out.pdb")
# Out:
# <Structure id=1bv1>

# %%
matplotlib.rcParams['figure.figsize'] = [24.0, 480.0]
seaborn.heatmap(
    df.pivot("resi", "resn", "ddG"),
    cmap="RdBu_r", center=0, vmax=5)
# Out:
# <AxesSubplot:xlabel='resn', ylabel='resi'>
