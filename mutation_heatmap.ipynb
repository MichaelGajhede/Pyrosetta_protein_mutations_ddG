# %%
import pandas as pd
import seaborn
import matplotlib

# %%
df = pd.read_csv ('1BV1_mut.csv')
print (df)
# Out:
#       Unnamed: 0  resi wt_resn resn      dG_mut       dG_wt       ddG
# 0              0     1       G    G -556.657149 -556.622811 -0.034338
# 1              1     1       G    A -557.548435 -556.622811 -0.925624
# 2              2     1       G    L -557.564223 -556.622811 -0.941413
# 3              3     1       G    M -556.510613 -556.622811  0.112198
# 4              4     1       G    F -557.435291 -556.622811 -0.812481
# ...          ...   ...     ...  ...         ...         ...       ...
# 3175        3175   159       N    H -555.640872 -556.622811  0.981938
# 3176        3176   159       N    R -556.931749 -556.622811 -0.308939
# 3177        3177   159       N    N -556.640039 -556.622811 -0.017229
# 3178        3178   159       N    D -554.927953 -556.622811  1.694857
# 3179        3179   159       N    T -556.561388 -556.622811  0.061422
#
# [3180 rows x 7 columns]

# %%
df.nlargest(5, ['ddG'])
# Out:
#       Unnamed: 0  resi wt_resn resn      dG_mut       dG_wt        ddG
# 910          910    46       G    P -494.850250 -556.622811  61.772561
# 1010        1010    51       G    P -498.766896 -556.622811  57.855914
# 1830        1830    92       G    P -499.691298 -556.622811  56.931513
# 950          950    48       G    P -500.101183 -556.622811  56.521628
# 285          285    15       A    W -516.266133 -556.622811  40.356677

# %%
df.nsmallest(200, ['ddG'])
# Out:
#       Unnamed: 0  resi wt_resn resn      dG_mut       dG_wt       ddG
# 607          607    31       P    Q -566.293981 -556.622811 -9.671170
# 608          608    31       P    E -564.650009 -556.622811 -8.027199
# 614          614    31       P    Y -563.957905 -556.622811 -7.335095
# 615          615    31       P    H -563.777547 -556.622811 -7.154736
# 601          601    31       P    A -563.757788 -556.622811 -7.134977
# ...          ...   ...     ...  ...         ...         ...       ...
# 1092        1092    55       K    I -558.051898 -556.622811 -1.429087
# 2108        2108   106       A    E -558.032017 -556.622811 -1.409207
# 1988        1988   100       N    E -558.027020 -556.622811 -1.404209
# 222          222    12       V    L -557.995203 -556.622811 -1.372392
# 3056        3056   153       A    R -557.985315 -556.622811 -1.362504
#
# [200 rows x 7 columns]

# %%
df_pivot = df.pivot("resi", "resn", "ddG")
df_pivot
# Out:
# resn         A         C         D         E         F         G         H  \
# resi
# 1    -0.925624  0.599444 -1.614370  1.370526 -0.812481 -0.034338 -0.726979
# 2     2.102694  2.860724  1.078415  0.497986  2.729819  4.031499  2.003883
# 3     2.931237  3.952772 -0.060358  4.476140  0.303292  5.113736  3.007855
# 4     2.219593  3.115064 -1.286021 -0.135980 -0.114793  4.246793  0.806678
# 5     2.733302  4.307383  3.977136  4.182494  0.257850  6.359351  2.398483
# ...        ...       ...       ...       ...       ...       ...       ...
# 155   1.390983  3.423146  3.273936  0.649913  3.406854  2.665773  2.262994
# 156   1.808270  3.781932 -0.038932  0.225162  1.220395  2.317638  1.530973
# 157  -0.078324  1.695930 -1.036875 -0.059269  0.610400  3.961095 -0.289752
# 158   5.359586  5.850911  2.816460  4.021239 -0.180510  7.346637  2.041444
# 159  -0.604248  1.262523  1.694857  2.856117  3.088797  1.138640  0.981938
#
# resn         I         K         L         M         N          P         Q  \
# resi
# 1    -0.865224 -2.053412 -0.941413  0.112198 -0.911657   0.420539 -0.821531
# 2     0.201027  3.971380  0.437851  2.047737  1.023018   5.469230  1.276452
# 3     1.087193  2.893751  3.105905  2.504012  2.328852   4.003362  1.922339
# 4    -0.514443  0.684915  0.022383  0.764957 -0.070563   0.737175  0.781213
# 5     6.913013  3.276882 -1.083139  0.010341  3.238002   5.956754  1.434743
# ...        ...       ...       ...       ...       ...        ...       ...
# 155   2.795227 -1.934994  1.046628  1.889044  2.049498  -3.436950 -0.319904
# 156   3.029883  0.597473  1.465844  2.919782  0.372692  12.268447 -0.189031
# 157   0.549194  0.034621 -0.154374  0.854615  1.507786  13.832838 -0.370183
# 158   9.273568  4.608360  5.876547  4.506398  2.324332  10.760905  3.277282
# 159   0.214945 -1.873930  0.837942  1.442439 -0.017229   8.429824  1.608963
#
# resn         R         S         T          V         W         Y
# resi
# 1    -3.503592 -0.306321  0.187305  -0.095110  2.037201 -1.759662
# 2     4.103764  3.943244  1.441929   0.068388  5.238337  2.488909
# 3     4.567844  5.089977  2.902024   0.292329  4.132333  0.178929
# 4     2.105979  2.453594  3.256966  -0.105563  2.883289 -0.396994
# 5     3.984734  3.664374  4.744656   1.966924  1.798860 -0.125764
# ...        ...       ...       ...        ...       ...       ...
# 155  -0.131735 -0.043606  1.099514   2.368701  2.473835  2.664421
# 156   1.972115  0.135429  0.871340   2.228370 -0.521498 -0.805691
# 157   1.003286  0.430395  0.861169   0.447485  9.225865  0.050881
# 158   5.626777  6.579219  8.315167  12.924402  2.564300 -0.118112
# 159  -0.308939 -0.225965  0.061422   0.730763  4.005994  2.276026
#
# [159 rows x 20 columns]

# %%
matplotlib.rcParams['figure.figsize'] = [24.0, 48.0]
seaborn.heatmap(
    df.pivot("resi", "resn", "ddG"),
    cmap="RdBu_r", center=0, vmax=5)
# Out:
# <AxesSubplot:xlabel='resn', ylabel='resi'>

# %%
df_mins = df_pivot.min(axis=1) #returns panda series which is an indexed 1d array
df_mins
# Out:
# resi
# 1     -3.852271
# 2     -0.162045
# 3      0.131341
# 4     -2.712195
# 5      6.584848
#          ...
# 155   -4.008303
# 156   -1.298567
# 157   -0.086099
# 158    1.405026
# 159   -1.873500
# Length: 159, dtype: float64

# %%
from Bio import *
from Bio.PDB import PDBParser, PDBIO

# %%
#map minimum dg's to 3D structure and store in b-factor column of pdb-file
io = PDBIO()
p = PDBParser()

structure = p.get_structure("1bv1", "1bv1_copy.pdb") # input files

for model in structure:
    for chain in model:
        for residue in chain:
            resi = residue.get_id()[1]
            #print(resi)
            bfac = df_mins.loc[resi]
            #print(bfac)
            for atom in residue:  
                atom.set_bfactor(bfac) # set b to ddG min for residue

print(structure)
io.set_structure(structure)
io.save("ddG_as_b.pdb")
# Out:
# <Structure id=1bv1>
